# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
import string
import seaborn as sns
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS as sklearn_stop_words

df = pd.read_csv(r'C:\Users\spoll\Desktop\Full Sail\Data Viz\Data_Visualization_And_Modeling_Online\Lab\Starbucks_reviews.csv')
df.head()
# Out:
#        name           location                     Date  Rating  \
# 0     Helen  Wichita Falls, TX  Reviewed Sept. 13, 2023     5.0
# 1  Courtney         Apopka, FL   Reviewed July 16, 2023     5.0
# 2  Daynelle  Cranberry Twp, PA    Reviewed July 5, 2023     5.0
# 3    Taylor        Seattle, WA    Reviewed May 26, 2023     5.0
# 4   Tenessa        Gresham, OR   Reviewed Jan. 22, 2023     5.0
#
#                                               Review  \
# 0  Amber and LaDonna at the Starbucks on Southwes...
# 1  ** at the Starbucks by the fire station on 436...
# 2  I just wanted to go out of my way to recognize...
# 3  Me and my friend were at Starbucks and my card...
# 4  I’m on this kick of drinking 5 cups of warm wa...
#
#                                          Image_Links
# 0                                      ['No Images']
# 1                                      ['No Images']
# 2  ['https://media.consumeraffairs.com/files/cach...
# ...

# %%
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data in Starbucks Reviews')
plt.show()

# %% [markdown]
# ## Missing Data
# The heatmap shows which features contain missing values. Yellow lines indicate
# missing data. Image_Links appears to have the most missing data.

# %%
sns.histplot(data=df, x='Rating', bins=10)
plt.title('Distribution of Starbucks Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

print(df['Rating'].describe())
# Out:
# count    705.000000
# mean       1.870922
# std        1.397672
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000
# Name: Rating, dtype: float64

# %% [markdown]
# ## Rating Distribution
# The histogram shows that Starbucks reviews are heavily skewed toward 5-star ratings,
# suggesting that most customers who leave reviews are satisfied with their experience.

# %%
all_reviews = ' '.join(df['Review'].astype(str))
words = all_reviews.lower().split()
words = [word.strip(string.punctuation) for word in words 
         if word.isalnum() 
         and word not in sklearn_stop_words 
         and len(word) > 2]

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(words))
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Words in Starbucks Reviews')
plt.show()

# %% [markdown]
# ## Review Word Cloud
# The word cloud shows the most common words in Starbucks reviews. Words like "coffee", "service", "order", and "staff" dominate, suggesting customers focus on service quality and their drink orders when writing reviews.
